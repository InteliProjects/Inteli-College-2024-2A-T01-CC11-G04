# %% [markdown]
# <a href="https://colab.research.google.com/github/Inteli-College/2024-2A-T01-CC11-G04/blob/104-rodar-modelos-com-nova-base-de-dados/notebooks/sprint4/extra_intentions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# ## Dados

# %%
csv_path = "/content/drive/MyDrive/Módulos/Módulo 11/data/data_2024-09-24_13-13-45.csv"
df = pd.read_csv(csv_path)
df = df.drop('processed_question', axis=1)
df.sample(3)
# Out:
#                         intent  \
# 1416        Como fazer remessa
# 3451                 Reembolso
# 610   Cadastro de beneficiario
#
#                                                question
# 1416   Sabe como posso transferir fundos para o Brasil?
# 3451  Boa noite, pessoal. Infelizmente, depositei um...
# 610   Oi, como cadastro um beneficiário para enviar ...

# %%
new_intents_path = "/content/drive/MyDrive/Módulos/Módulo 11/data/new_intents.csv"
df_n = pd.read_csv(new_intents_path)
df_n = df_n.rename(columns={'pergunta': 'question', 'intencao': 'intent'})
df_n.sample(3)
# Out:
#                                              question               intent
# 91        Como posso ligar para o suporte ao cliente?  falar com atendente
# 72  Posso falar diretamente com uma pessoa do aten...  falar com atendente
# 54  Quais são as opções para falar com o suporte h...  falar com atendente

# %%
print(len(df))
print(len(df_n))
# Out:
# 5100
# 99

# %%
df_combined = pd.concat([df, df_n], ignore_index=True)
df_combined.sample(5)
# Out:
#                            intent  \
# 2333  Confirmacao de cambio/taxas
# 236                Acesso a conta
# 2622            Como se inscrever
# 1389           Como fazer remessa
# 4896   Tempo de entrega do cartao
#
#                                                question
# 2333  Preciso saber a conversão de 520 reais para ye...
# 236   Boa noite, estou encontrando dificuldades para...
# 2622  Preciso de orientação para efetuar a inscrição...
# 1389  Dá pra me explicar como que faz pra mandar gra...
# 4896  Oi, fiz um depósito sem o cartão porque ele ai...

# %%
len(df_combined)
# Out:
# 5199

# %%
df_combined.sample(3)
# Out:
#                              intent  \
# 4483  Termos e condicoes do servico
# 2485    Confirmacao de cambio/taxas
# 3471                      Reembolso
#
#                                                question
# 4483  Boa tarde\ngostaria de saber se vcs enviam din...
# 2485  Bom dia depositei ontem y59.000 quanto chega n...
# 3471         O dinheiro do reembolso demora pra entrar?

# %%
intent_counts = df_combined['intent'].value_counts()
print(intent_counts)
# Out:
# intent
# Confirmacao de cambio/taxas           310
# Acesso a conta                        300
# Envio via Deposit Code                300
# Tempo de entrega do cartao            300
# Solicitacao de cartao de remessas     300
# Tempo de remessa                      300
# Registro/Atualizacao de Documento     300
# Reembolso                             300
# Pedido de envio via metodo ByPhone    300
# Como se inscrever                     300
# Atualizacao de dados cadastrais       300
# Como depositar                        300
# Cancelamento                          300
# Como fazer remessa                    300
# Problemas de remessa                  300
# Cadastro de beneficiario              300
# Termos e condicoes do servico         290
# desqbilutou                            51
# falar com atendente                    48
# Name: count, dtype: int64

# %%
output_path = "/content/drive/MyDrive/Módulos/Módulo 11/data/data_with_new_intents.csv"
df_combined.to_csv(output_path, index=False)
